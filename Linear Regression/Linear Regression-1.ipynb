# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
#linear regression learning period.

# %%
df=pd.read_csv("C:\\Users\\Dev Atul Patel\\OneDrive\\Documents\\homeprice.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price)

# %%
reg=linear_model.LinearRegression()
reg.fit(df[["area"]],df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
reg.predict([[20000]])
# Out:
# C:\Python39\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2896369.8630137])

# %%
# %matplotlib inline
plt.xlabel('area',fontsize=10)
plt.ylabel('price',fontsize=10)
plt.scatter(df.area,df.price,color='blue',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')
